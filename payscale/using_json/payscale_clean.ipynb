# %%
# import libraries
import pandas as pd

# %% [markdown]
# ---
#  # Location
#
# ---

# %%
df_location = pd.read_csv('https://raw.githubusercontent.com/szilvasipeter2000/Web_Scraping/main/payscale/using_json/data/data_location.csv')
df_location
# Out:
#                                    name  displayName  \
# 0                    New York, New York          NaN
# 1                      Atlanta, Georgia          NaN
# 2                Minneapolis, Minnesota          NaN
# 3      Washington, District of Columbia          NaN
# 4                         Dallas, Texas          NaN
# ...                                 ...          ...
# 32658                  Atlanta, Georgia          NaN
# 32659           Santa Clara, California          NaN
# 32660             San Diego, California          NaN
# 32661                New York, New York          NaN
# 32662                 Chicago, Illinois          NaN
#
#                                                      url  profileCount  \
# 0      /research/US/Job=ABAP_Developer/Salary/a7aeab5...            10
# 1      /research/US/Job=ABAP_Developer/Salary/e4c182a...             8
# 2      /research/US/Job=ABAP_Developer/Salary/3a68bbf...             5
# ...

# %% [markdown]
# ---
#  # Employer
#
# ---

# %%
df_employer = pd.read_csv('https://raw.githubusercontent.com/szilvasipeter2000/Web_Scraping/main/payscale/using_json/data/data_employer.csv')
df_employer
# Out:
#                                               name  displayName  \
# 0                                Intel Corporation          NaN
# 1                             Lockheed Martin Corp          NaN
# 2                     Advanced Micro Devices, Inc.          NaN
# 3                             Broadcom Corporation          NaN
# 4                           Juniper Networks, Inc.          NaN
# ...                                            ...          ...
# 6665                      Georgia State University          NaN
# 6666  West Virginia School of Osteopathic Medicine          NaN
# 6667                                    Blockhouse          NaN
# 6668                     Boston Symphony Orchestra          NaN
# 6669                  Norfolk Southern Corporation          NaN
#
#                                                     url  profileCount  \
# 0     /research/US/Job=ASIC_Design_Engineer/Salary/c...             9
# ...

# %% [markdown]
# ---
#  # Skills
#
# ---

# %%
df_skills = pd.read_csv('https://raw.githubusercontent.com/szilvasipeter2000/Web_Scraping/main/payscale/using_json/data/data_skill.csv')
df_skills
# Out:
#                                                     name  displayName  \
# 0                                               SAP ABAP          NaN
# 1                 SAP Enterprise Resource Planning (ERP)          NaN
# 2      Advanced Business Application Programming (ABA...          NaN
# 3                      Object Oriented Programming (OOP)          NaN
# 4                                                 ABAP/4          NaN
# ...                                                  ...          ...
# 16240                        Embedded / Real-Time / RTOS          NaN
# 16241                                           Wireless          NaN
# 16242                                   Cisco Networking          NaN
# 16243                       Wireless Data Communications          NaN
# 16244                                             Design          NaN
#
#                                                      url  profileCount  \
# ...

# %% [markdown]
# ---
#  # Experience
#
# ---

# %%
df_experience = pd.read_csv('https://raw.githubusercontent.com/szilvasipeter2000/Web_Scraping/main/payscale/using_json/data/data_experience.csv')
df_experience
# Out:
#                   name  displayName  \
# 0     Less than 1 year          NaN
# 1            1-4 years          NaN
# 2            5-9 years          NaN
# 3          10-19 years          NaN
# 4     20 years or more          NaN
# ...                ...          ...
# 2641       10-19 years          NaN
# 2642  20 years or more          NaN
# 2643         1-4 years          NaN
# 2644         5-9 years          NaN
# 2645       10-19 years          NaN
#
#                                                     url  profileCount  \
# 0     /research/US/Job=ABAP_Developer/Salary/6b5bb51...             5
# 1     /research/US/Job=ABAP_Developer/Salary/6b5bb51...            10
# 2     /research/US/Job=ABAP_Developer/Salary/5357002...            17
# 3     /research/US/Job=ABAP_Developer/Salary/637c754...            14
# 4     /research/US/Job=ABAP_Developer/Salary/80a9e6f...            14
# ...                                                 ...           ...
# ...

# %% [markdown]
# ---
#  # Summary
#
# ---

# %%
df_summary = pd.read_csv('https://raw.githubusercontent.com/szilvasipeter2000/Web_Scraping/main/payscale/using_json/data/data_summary.csv')
df_summary
# Out:
#                                   job_title  \
# 0                            ABAP Developer
# 1                      ASIC Design Engineer
# 2                             ASIC Engineer
# 3                         ASP.NET Developer
# 4                       Actuarial Associate
# ..                                      ...
# 657                               Webmaster
# 658                         Website Manager
# 659                          Website Tester
# 660        Wireless Communications Engineer
# 661  Wireless Network Optimization Engineer
#
#                                               category  \
# 0             15-1030.00 - Computer Software Engineers
# 1             15-1030.00 - Computer Software Engineers
# 2    15-1030.00 - Unclassified Computer Software En...
# 3             15-1030.00 - Computer Software Engineers
# 4                               15-2010.00 - Actuaries
# ..                                                 ...
# ...
